# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Đọc dữ liệu từ các file CSV
file_paths = {
    "Euclidean Distance top 1": "../experimental/top_1_Euclidean Distance.csv",
    "Euclidean Distance top 3": "../experimental/top_3_Euclidean Distance.csv",
    "Euclidean Distance top 5": "../experimental/top_5_Euclidean Distance.csv",
}

dataframes = {key: pd.read_csv(path) for key, path in file_paths.items()}

# Vẽ biểu đồ
plt.figure(figsize=(16, 8))

# Lấy danh sách threshold
thresholds = dataframes["Euclidean Distance top 1"]["Threshold"]

t1, t2, t3 = (
    dataframes["Euclidean Distance top 1"],
    dataframes["Euclidean Distance top 3"],
    dataframes["Euclidean Distance top 5"],
)

f1 = {
    "Euclidean Distance top 1": t1["F1-Score"],
    "Euclidean Distance top 3": t2["F1-Score"],
    "Euclidean Distance top 5": t3["F1-Score"],
}

# Xác định vị trí cột trên trục x
x = np.arange(len(thresholds))
width = 0.25

# Vẽ biểu đồ cột
plt.bar(x - width, f1["Euclidean Distance top 1"], width, label="Top 1")
plt.bar(x, f1["Euclidean Distance top 3"], width, label="Top 3")
plt.bar(x + width, f1["Euclidean Distance top 5"], width, label="Top 5")

# Gắn nhãn
plt.xlabel("Threshold")
plt.ylabel("F1-Score")
plt.title("F1-Score Across Different Top_k of Euclidean Distance")

plt.xticks(x, thresholds, rotation=45)
plt.yticks(np.arange(0.0, 1.1, 0.1))

plt.legend()
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Điều chỉnh layout để tránh bị cắt nhãn
plt.tight_layout()

# Hiển thị biểu đồ
plt.show()

# %%
# Đọc dữ liệu từ các file CSV
file_paths = {
    "Cosine similarity top 1": "../experimental/top_1_Cosine similarity.csv",
    "Cosine similarity top 3": "../experimental/top_3_Cosine similarity.csv",
    "Cosine similarity top 5": "../experimental/top_5_Cosine similarity.csv",
}

dataframes = {key: pd.read_csv(path) for key, path in file_paths.items()}

# Vẽ biểu đồ
plt.figure(figsize=(16, 8))

# Lấy danh sách threshold
thresholds = dataframes["Cosine similarity top 1"]["Threshold"]

t1, t2, t3 = (
    dataframes["Cosine similarity top 1"],
    dataframes["Cosine similarity top 3"],
    dataframes["Cosine similarity top 5"],
)

f1 = {
    "Cosine similarity top 1": t1["F1-Score"],
    "Cosine similarity top 3": t2["F1-Score"],
    "Cosine similarity top 5": t3["F1-Score"],
}

# Xác định vị trí cột trên trục x
x = np.arange(len(thresholds))
width = 0.25

# Vẽ biểu đồ cột
plt.bar(
    x - width, f1["Cosine similarity top 1"], width, label="Cosine similarity top 1"
)
plt.bar(x, f1["Cosine similarity top 3"], width, label="Cosine similarity top 3")
plt.bar(
    x + width, f1["Cosine similarity top 5"], width, label="Cosine similarity top 5"
)

# Gắn nhãn
plt.xlabel("Threshold")
plt.ylabel("F1-Score")
plt.title("F1-Score Across Different Top_k of Cosine similarity")

plt.xticks(x, thresholds, rotation=45)
plt.yticks(np.arange(0.0, 1.1, 0.1))

plt.legend()
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Điều chỉnh layout để tránh bị cắt nhãn
plt.tight_layout()

# Hiển thị biểu đồ
plt.show()

# %%
# Đọc dữ liệu từ các file CSV
file_paths = {
    "Pearson Corr top 1": "../experimental/top_1_Pearson Corr.csv",
    "Pearson Corr top 3": "../experimental/top_3_Pearson Corr.csv",
    "Pearson Corr top 5": "../experimental/top_5_Pearson Corr.csv",
}

dataframes = {key: pd.read_csv(path) for key, path in file_paths.items()}

# Vẽ biểu đồ
plt.figure(figsize=(16, 8))

# Lấy danh sách threshold
thresholds = dataframes["Pearson Corr top 1"]["Threshold"]

t1, t2, t3 = (
    dataframes["Pearson Corr top 1"],
    dataframes["Pearson Corr top 3"],
    dataframes["Pearson Corr top 5"],
)

f1 = {
    "Pearson Corr top 1": t1["F1-Score"],
    "Pearson Corr top 3": t2["F1-Score"],
    "Pearson Corr top 5": t3["F1-Score"],
}

# Xác định vị trí cột trên trục x
x = np.arange(len(thresholds))
width = 0.25

# Vẽ biểu đồ cột
plt.bar(x - width, f1["Pearson Corr top 1"], width, label="Top 1")
plt.bar(x, f1["Pearson Corr top 3"], width, label="Top 3")
plt.bar(x + width, f1["Pearson Corr top 5"], width, label="Top 5")

# Gắn nhãn
plt.xlabel("Threshold")
plt.ylabel("F1-Score")
plt.title("F1-Score Across Different Top_k of Pearson Corr")

plt.xticks(x, thresholds, rotation=45)
plt.yticks(np.arange(0.0, 1.1, 0.1))

plt.legend()
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Điều chỉnh layout để tránh bị cắt nhãn
plt.tight_layout()

# Hiển thị biểu đồ
plt.show()
